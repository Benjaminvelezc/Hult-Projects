# %%
"""
This is a game by Benjamin Velez, inspired by the Indiana Jones movie Raiders of the Lost Arc. The purpose 
of the game is to clear the stages and retrieve the golden idol without dying by typing the correct actions in 
order to clear the traps and situation in the temple. You can either type your answer or its number, there is only 
potential bug identified so far, which is missing words within the conditional statements which the player might type
for their actions and the game would not recognize and repeat the question again. To avoid bugs no input in the
game is an int. All loops are numbered in the stageto make it easier to follow the code along.
Please enjoy and best of luck!
"""
#lists and variables for answers to yes or no questions
gg = 0
start = ""
co = 0
lsty = ["yes", "y", "sure", "correct", "affirmative", "si", "yep", "aha", "1", "go"]
lstn = ["no", "negative", "incorrect", "false", "never", "wrong", "nope", "0", "2", "esc"]
def gend():
    "Function for when player quits game."
    co = 0
    a = input ("""Main menu, press enter to begin""")
    start = input ("""Welcome to Raiders of the Lost Python, a pick a path Indiana Jones game
do you want to start? Y/N

""")
    while co < 1:
        for resp in lsty:
            if start in resp or resp in start:
                game()
                co = 1
                break
        for resp in lstn:    
            if start in resp or resp in start:
                print ("Game over")
                co = 1
                break
        if co == 0:
            print ("Please enter a valid option")

def win():
    "function for winning the game."    
    print (f"""
    You arrive back home with Indiana Jones and hand him the idol of Chachapoyan "Thank you, I couldn't have done
    this without you, I will give this to the U.S. government at the university and you know what, I will 
    also speak with them about getting you a position working with me once you graduate if you'd like, that is, 
    if you manage to stay awake during classes.""")
    co = 0  
    cont = input ("""
                    _,.---._                                ,-.-.  .=-.-..-._         .=-.-. 
     ,--.-.  .-,--.,-.' , -  `.  .--.-. .-.-.       ,-..-.-./  \==\/==/_ /==/ \  .-._ /==/_ / 
    /==/- / /=/_ //==/_,  ,  - \/==/ -|/=/  |       |, \=/\=|- |==|==|, ||==|, \/ /, /==|, |  
    \==\, \/=/. /|==|   .=.     |==| ,||=| -|       |- |/ |/ , /==/==|  ||==|-  \|  ||==|  |  
     \==\  \/ -/ |==|_ : ;=:  - |==|- | =/  |        \, ,     _|==|==|- ||==| ,  | -|/==/. /  
      |==|  ,_/  |==| , '='     |==|,  \/ - |        | -  -  , |==|==| ,||==| -   _ |`--`-`   
      \==\-, /    \==\ -    ,_ /|==|-   ,   /         \  ,  - /==/|==|- ||==|  /\ , | .=.     
      /==/._/      '.='. -   .' /==/ , _  .'          |-  /\ /==/ /==/. //==/, | |- |:=; :    
      `--`-`         `--`--''   `--`..---'            `--`  `--`  `--`-` `--`./  `--` `=` 
      
                              Would you like to play again? Y/N
        """)
    cont = cont.casefold()
    while co < 1:
        for resp in lsty:
            if cont in resp or cont in start:
                game()
                co = 1
                break
        for resp in lstn:    
            if cont in resp or resp in cont:
                print ("Thanks for playing!")
                co = 1
                gend()
                break
        print ("Please enter a valid option")
        

def fail():
    "function for when player dies"    
    lsty = ["yes", "y", "sure", "correct", "affirmative", "si", "yep", "aha", "1", "go"]
    lstn = ["no", "negative", "incorrect", "false", "never", "wrong", "nope", "0", "2"]
    co = 0
    cont = ""
    cont = input ("""
                        )            (                _____ 
                      ( /(           )\ )           ) |   / 
                      )\())     (   (()/(        ( /( |  /  
                      ((_)\(   ))\  /(_)) (  (  )\()) | /   
                    __ ((_))\ /((_) (_))   )\ )\(_))/ |/    
                    \ \ / ((_|_))(  | |   ((_|(_) |_ (      
                     \ V / _ \ || | | |__/ _ (_-<  _|)\     
                      |_|\___/\_,_| |____\___/__/\__((_)    
                        Would you like to play again?
                                    Y/N
                                    
                        """)
    cont = cont.casefold()
    while co < 1:
        for resp in lsty:
            if cont in resp or resp in cont:
                game()
                co = 1
                break
        for resp in lstn:    
            if cont in resp or resp in cont:
                print ("Thanks for playing!")
                co = 1
                gend()
                break
            print ("Please enter a valid option")
                        
def game():
    "Command to start game"
    co = 0
#variables for loops to ensure correct answers
    q = 0
    c = ""
    br = "" 

#prologue
    print ("""You wake up at your desk at Princeton and you realize your archeology class is over, 
everbody else had left except for professor Jones, once he notices you are awake he walks towards you 
"Well hello student, its nice of you to finally wake up" """)
    #loop for naming yourself
    while q < 1:
        name = input("    Could you please tell me your name again? ")
        ans = input (f"    Sorry did you say your name was {name}? ")
        ans = ans.casefold()
        for a in lsty:
            if ans in a or a in ans or name == ans:
                q = 1
                
    print (f"""    Well i can see that you are a brilliant student, but you dont seem very motivated, look
    {name} im going on a sort of work trip and im understaffed but I think you can handle it,
    come with me on this adventure and I guarantee that if you survive it will change your life!
    
    Without giving you a second to answer the professor grabs you and says "Come on! The plane leaves in 30 minutes"
    """)
    br = input ("""
    Press enter to continue
    
    """)


#stage 1, arriving to the temple
    inventory = ["Flashlight", "Rope", "Water", "Jacket", "Knife"]
    print(f"""    You arrive in the middle of a jungle somewhere in south america and the professor gives 
    you a change of clothes and a bag and says "Come on get ready we have an 8 hour walk to get
    to the newly discovered temple" you say "Thanks professor Jones" to which he replies 
    "Come on {name}, we are going on an adventure together, you can call me Indiana, now get ready
    I have hired some locals to guide us through the jungle"

          """)
#try-except code to know where problems arise, this can be found in all stages    
    try:
        br = input ("""
        Press enter to continue

        """)
        print(f"""    6 hours into your walk the group finds arrows and darts scattered all over the trees in the area, 
    the locals start discussing in Spanish and they sound afraid, soon after one of them pulls
    out a gun and aims it at Indiana Jones who has his back turned against them

            """)

    #scene based on one of the best character introductions of all time
        #loop 1
        q = 0
        while q < 1:
            ans = input ("""    What will you do?
    1. Fight
    2. Scream
    3. Run away

        """)
            if "1" in ans or "fight" in ans.casefold() or ans.casefold() == "one":
                print ("""    
    You punch the man besides the one who drew the gun and just as you are trying to reach
    for the gun a whip knocks it out of the man's hand and both of them run away screaming. 
    "Good instincts kid" says Indiana as he ties the whip again, now come on, we are almost there.

            """)
                q = 1
            elif "2" in ans or "scream" in ans.casefold() or ans.casefold() == "two" or ans.casefold() == "shout":
                print ("""    You scream "Indiana!" to the top of your lungs as he takes out his whip uses it to knock
    the gun out of the man's hand and hits the other man whose gun was pointing at you, both men run away 
    and Indiana looks at you and says "you need to learn how to fight, by screaming the other guy almost 
    shot you, now lets keep moving."

                """)
                q = 1
            elif "3" in ans or "run" in ans.casefold() or ans.casefold() == "three":
                q = 1
                print ("""You start running away when you hear a commotion behing you and a bullet hits you 
from behind.
                """)
                fail()
            else:
                print ("    Please enter a valid option.")
                #end loop 1

        print ("""    
    You finally arrive at the temple, Indiana looks around and says "This is definitely neither Aztec or Toltec" 
    as he says that you remember from one of his classes how the Aztecs worshiped Huitzilopochtli the eagle
    while the Toltecs worshiped Tezcatlipoca the jaguar, when he realized you were lost in thought the professor
    said as he filled a bag with dirt "remember to check your bag, you never know what you are going to need".
    You open up your bag and start checking, you find out you have:
            """)
        for item in inventory:
            print (f"""        {item}""")
        print ("""
    Indiana gives you the dirt and a gun "take this, I took it from one of our friends earlier 
    and even though it only has a bullet left it could help, also the dirt could be useful so put both of 
    them in your bag, now, lets go inside!"
        """)
        inventory.append("Gun")
        inventory.append("Dirt")
        br = input ("""
    Press enter to continue.

        """)
    except:
        print ("Error in stage 1")


#stage 2, entering the temple
    print ("""
    You enter the temple with Indiana Jones but shortly after you step on a preassure plate and the floor
    behind you splits, you manage to get away but the professor gets thrown into a dark pit. You try to look
    down when you hear him say "im alright, there is a path down here, keep going and i'll catch up"
    terrified you keep walking through the temple only to find yourself in a fork with 3 paths, one of them
    has an eagle statue, the other a jaguar statue and the last path has a statue that looked destroyed by
    the elements, you dont know what traps await you but you are sure there's something you should remember...

        """)
#fork on the road trap based on memory from stage 1
    q = 0
    try:
    #loop 1    
        while q < 1:
            ans = input ("""Which path will you take?
        1. Eagle
        2. Jaguar
        3. Other

            """)
            if "1" in ans or "eagle" in ans.casefold() or ans.casefold() == "one":
                q = 1
                print ("You go through the eagle path and after taking 10 steps you are hit by a volley of darts.")
                fail()
            elif "2" in ans or "jaguar" in ans.casefold() or ans.casefold() == "two":
                q = 1
                print ("You go through the jaguar path and after taking 15 steps the floor opens and you fall in spikes.")
                fail()
            elif "3" in ans or "other" in ans.casefold() or ans.casefold() == "three" or "unknown" in ans.casefold() or "destroyed" in ans.casefold():
                q = 1
                print(f"""    You remember that since the temple isn't Aztec or Toltec the safe bet was to take the other path,
     as you continue walking you hear a man limping and as you approach you see that it's Indiana 
    "oh hey {name} its good to see you are still alive, now help me I injured my leg".

You proceed deeper into the temple.

                """)
            else:
                print ("    Please enter a valid option.")
                #end loop 1
    except:
        print ("Something went wrong in stage 2.")
    br = input ("""
    Press enter to continue.
    
    """)

#stage 3, traps and treassures
    print (f"""    As you follow the path you see what appears to be a staircase to an altar "{name} im going to have 
    to ask you to get the idol from that altar" says Indiana "with my injuries I can't go up those stairs."
    
    As you climb the stairs you see a golden idol in the middle of the altar, as you reach for it you notice a
    small crack in the altar surrounding the idol, you realice that this is a preassure plate and it could 
    activate a trap once the weight is released.
    """)
    q = 0
    q2 = 0
    q3 = 0
    q4 = 0
#one of the best known movie scenes, with a loops within a loops
    try:
        #start of loop 1
        while q < 1:
            ans = input ("""    What will you do?
    1. Look around
    2. Check your bag
    3. Grab idol and run! 

        """)
            if ("1" in ans or "look" in ans.casefold() or ans.casefold() == "one" or "search" in ans.casefold() or "around" in ans.casefold() or "find" in ans.casefold()) and not ("bag" in ans.casefold()):
                print ("    There appears to be nothing usefull around the altar.")
            elif "2" in ans or "check" in ans.casefold() or ans.casefold() == "two" or "bag" in ans.casefold() or "inv" in ans.casefold() or "open" in ans.casefold():
                q = 1
                print ("""You check your bag and you find the following items:

                """)
                for item in inventory:
                    print (f"""    {item}""")
                print ("""

                """)
                #start of loop 2
                while q2 <1:
                    ans2 = input ("Which item will you take out?")
                    if "dirt" in ans2.casefold() or "sand" in ans2.casefold() or "bag" in ans2.casefold() or "gave" in ans2.casefold():
                        q2 = 1
                        print ("""    You grab the dirt but it feels a bit heavy and tied to strongly.""")
                        #start of loop 3
                        while q3 < 1:
                            ans3 = input ("""What will you do?
    1. Use the dirt to replace idol
    2. Get something else out of the bag
    3. Put the dirt back in the bag

        """)
                            if "replace" in ans3.casefold() or "use" in ans3.casefold() or "idol" in ans3.casefold() or "gave" in ans3.casefold() or "1" in ans3.casefold() or "one" in ans3.casefold():
                                print ("The dirt was to heavy! as soon as you switch it with the idol you get crushed by a boulder.")
                                q3 = 1
                                fail()
                            elif "put" in ans3.casefold() or "back" in ans3.casefold() or "3" in ans3.casefold() or "three" in ans3.casefold():
                                q2 = 0
                                q3 = 1    
                            elif "something" in ans3.casefold() or "else" in ans3.casefold() or "bag" in ans3.casefold() or "2" in ans3.casefold() or "two" in ans3.casefold():
                                q3 = 1
                                #start of loop 4
                                while q4 <1:
                                    ans4 = input ("Which item will you take out?")
                                    if "knife" in ans4.casefold():
                                        print ("""    
    You take the knife and cut a hole in the bag until a bit of dirt falls through, then swiftly 
    you replace the idol with the dirt and make your triumphant return down the stairs.

            """)
                                        inventory.append("Idol")
                                        q4 = 1
                                    elif "water" in ans4.casefold():
                                        q4 = 1
                                        print ("""    You add water to the dirt through the cloth of the bag and replace the idol, with the added 
    weight from the water, the pressure plate goes down and a boulder crushes you.""")
                                        fail()
                                    elif ans4.casefold().capitalize() in inventory or "flashlight" in ans4.casefold() or "rope" in ans4.casefold() or "jacket" in ans4.casefold() or "gun" in ans4.casefold():
                                        print ("You reach out for the item but you realize it couldnt help.")
                                    else:
                                        print ("Please enter a valid option.")
                                        #end of loop 4

                            else:
                                print ("Please select a valid option.")
                                #end of loop 3

                    elif ans2.casefold().capitalize() in inventory or "flashlight" in ans2.casefold() or "rope" in ans2.casefold() or "water" in ans2.casefold() or "jacket" in ans2.casefold() or "knife" in ans2.casefold() or "gun" in ans2.casefold():
                        q2 = 1
                        print ("""    You take out the item and swiftly replace it with the idol on the preassure plate, 
    seconds after, the plate moves and a huge boulder crushes you.""")
                        fail()   
                    else:
                        print ("Please enter a valid item.")
                        #end of loop 2 

            elif "3" in ans or "grab" in ans.casefold() or ans.casefold() == "three" or "run" in ans.casefold() or "take" in ans.casefold() or "escape" in ans.casefold() or "flee" in ans.casefold() or "idol" in ans.casefold():
                q = 1
                print("""You take the idol and begin to run away only to be crushed by a boulder.""")
                fail()

            else:
                print ("Please enter a valid option.")
                #end of loop 1
    except:
        print ("Error in stage 3")

#stage 4, escape!
    print ("""    You show the idol to Indiana Jones and he says "That looks amazing! Its an idol of Chachapoyan, 
    put it in your bag and lets get out of here" you tell him about the pressure plate as you walk out when he 
    asks "great thinking but did you make sure to put the hole facing upwards so the dirt wouldnt slide?" then 
    as if waiting for that comment a giant boulder lands on top of the altar and begins rolling your way.""")
    q = 0
    q2 = 0
    q3 = 0
    q2b = 0
    
    try:
        #start of loop 1
        while q < 1:
            ans = input ("""    A huge boulder is racing towards you! What will you do?
    1. Look around
    2. Run!
    3. Pray to Chachapoyan
    4. Shoot the boulder in the center

        """)
            ans = ans.casefold()
            if "look" in ans or "search" in ans or "around" in ans or "1" in ans or "one" in ans:
                print ("You look around and se a small hole in the wall 2 meters away...")
                q = 1
                #start of loop 2
                while q2 < 1:
                    ans2 = input ("""Will you jump in?
    1. Jump!
    2. Run!

        """)
                    ans2 = ans2.casefold()
                    if "jump" in ans2 or "1" in ans2 or "one" in ans2 or "hole" in ans2 or "y" in ans2 or "grab" in ans2:
                        print (f"""    You grab Indiana and jump in the hole, seconds after you hear the boulder roll through
    "Wow {name} I thought I was going to die, thanks" but now how do we get out of this hole? 
                        """)
                        q2 = 1
                    elif "run" in ans2 or "escape" in ans2 or "flee" in ans2 or "2" in ans2 or "two" in ans2:
                        print ("""You start to run but the boulder crushes you.""")
                        q2 = 1
                        fail()
                    else:
                        print ("Please enter a valid option.")
                        #end of loop 2
            elif "run" in ans or "escape" in ans or "flee" in ans or "2" in ans or "two" in ans:
                #start of loop 2b
                q = 1
                while q2b < 1:
                    ans2b = input ("""You start running and Indiana Jones screams "Help! I cant run!"
    What do you do?

    1. Go back for him
    2. Run! Every man for himself

        """)
                    ans2b = ans2b.casefold()
                    if "back" in ans2b or "him" in ans2b or "indiana" in ans2b or "1" in ans2b or "one" in ans2b:
                        print ("You return and grab Indiana Jones but its too late and the boulder crushes you.")
                        fail()
                        q2b = 1
                    elif "run" in ans2b or "escape" in ans2b or "flee" in ans2b or "2" in ans2b or "two" in ans2b or "every" in ans2b:
                        print ("""You keep running as you hear a crushing sound behind you, then as you approach a turn
    in the corridor you step on a pressure plate and fall on some deadly spikes.""")
                        fail()
                        q2b = 1
                    else: 
                        print ("Please enter a valid option.")
                        #end loop 2b
            elif "pray" in ans or "Chachapoyan" in ans or "worship" in ans or "3" in ans or "three" in ans:
                print ("Your prayers do nothing and you are crushed by the boulder")
                q = 1
                fail()
            elif "shoot" in ans or "boulder" in ans or "gun" in ans or "4" in ans or "four" in ans or "fire" in ans:
                print ("The last thing you hear is Indiana Jones calling you an idiot before you both get crushed.")
                q = 1
                fail()   
            else:
                print ("Please enter a valid option")
                #end of loop 1

        print ("""As you get up from the ground you grab your flashlight to find if you can climb back out, but you are
    shocked to se that that you are not alone, as there are a lot of snakes in the hole.""") 
        #start of loop 3
        while q3 < 1:
            ans3 = input ("""
    What do you do?

    1. Scream and try to climb
    2. Slowly help Indiana up and tell him
    3. Shoot the gun to scare the snakes away

        """)
            ans3 = ans3.casefold()
            if "scream" in ans3 or "climb" in ans3 or "shoot" in ans3 or "gun" in ans3 or "scare" in ans3 or "away" in ans3 or "1" in ans3 or "one" in ans3 or "3" in ans3 or "three" in ans3:
                print ("The noise scares the snakes and they attack both of you.")
                q3 = 1
                fail()
    #easter egg
            elif "snakes" in ans3 and "why" in ans3 and "did" in ans3:
                print ("""    You and Indiana simultaneously say “Snakes! Why did it have to be snakes?” then you decide to
    slowly climb up the wall and toss the rope to bring Indiana back up, once you are both up, he 
    says "you know im starting to really like you, both of us even hate snakes, you will
    definitely get an A on my class!" 
    You help Indiana and walk together towards the exit of the temple.
                """)
                q3 = 1
                win()
                break
    #end of easter egg
            elif "slowly" in ans3 or "help" in ans3 or "tell" in ans3 or "indiana" in ans3 or "him" in ans3 or "2" in ans3 or "two" in ans3:
                print ("""    Once you tell him Indiana Jones says “Snakes! Why did it have to be snakes?” he then instructs you 
    to quietly climb up without upsetting the snakes and then to help him climb up using your rope.
    Both of you start heading out of the temple.
                """)
                q3 = 1
                win()
            else:
                print ("Please enter a valid option")
                #end of loop 3
        br = input ("""
    Press enter to continue

        """)
    except:
        print ("There is an error in stage 4")
if gg == 0:    
    #This starts the game
    start = input ("""Welcome to Raiders of the Lost Python, a pick a path Indiana Jones game
do you want to start? Y/N

""")
    start = start.casefold()
    while co < 1:
        for resp in lsty:
            if start in resp or resp in start:
                game()
                co = 1
                break
        for resp in lstn:    
            if start in resp or resp in start:
                print ("Game over")
                co = 1
                gend()
                break
        if co == 0:
            print ("Please enter a valid option")
# Out:
# Welcome to Raiders of the Lost Python, a pick a path Indiana Jones game
# do you want to start? Y/N
#
# y
# You wake up at your desk at Princeton and you realize your archeology class is over,
# everbody else had left except for professor Jones, once he notices you are awake he walks towards you
# "Well hello student, its nice of you to finally wake up"
#     Could you please tell me your name again? b
#     Sorry did you say your name was b? y
#     Well i can see that you are a brilliant student, but you dont seem very motivated, look
#     b im going on a sort of work trip and im understaffed but I think you can handle it,
#     come with me on this adventure and I guarantee that if you survive it will change your life!
#
#     Without giving you a second to answer the professor grabs you and says "Come on! The plane leaves in 30 minutes"
#
#
#     Press enter to continue
#
#
#     You arrive in the middle of a jungle somewhere in south america and the professor gives
# ...
